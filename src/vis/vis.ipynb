# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
DATA_PATH = "../../data/experiments/"

# %%
y= [215, 122, 5.92, 6.14, 6.01, 5.2]
y2= [7.6, 8.6, 8.7, 8.1, 8.3, 8.1]
x_values = ["1", "0.25", "0.20", "0.15", "0.05", "0.01"]
x=np.arange(len(x_values))

fig, ax1 = plt.subplots(layout='constrained', figsize=[6.4*2, 4.8*2])
ax2 = ax1.twinx()


ax1.bar(x-0.2, y, 0.4, label='PercentError', color='green')
ax1.set_ylabel('PercentError', color='green')
ax1.set_xlabel('b-value')
ax1.set_xticks(x)
ax1.set_xticklabels(x_values)

ax2.bar(x+0.2, y2, 0.4,label='Time', color='red')
ax2.set_ylabel('Median Time (in s)', color='red')

plt.title("Error and Runtime for different b-values")
plt.show()

# %%
plt.rcParams.update({'font.size': 12})
y= [215, 122, 5.92, 6.14, 6.01, 5.2]
y2= [7.6, 8.6, 8.7, 8.1, 8.3, 8.1]
x_values = ["1", "0.25", "0.20", "0.15", "0.05", "0.01"]
x=np.arange(len(x_values))

fig, ax = plt.subplots(figsize=[6.4*1.5, 4.8*1.5])

ax.bar(x, y, label='Percent Error', color='#dc3c06')
ax.set_ylabel('PercentError')
ax.set_xlabel('b-value')
ax.set_xticks(x)
ax.set_xticklabels(x_values)

for i in range(len(x)):
    plt.text(i, y[i], f"{round(y[i],1)}%", ha = 'center')

plt.title("Error for different b-values")
plt.show()
plt.rcParams.update({'font.size': 10})

# %%
plt.rcParams.update({'font.size': 12})
y2= [7.6, 8.6, 8.7, 8.1, 8.3, 8.1]

fig, ax = plt.subplots(figsize=[6.4*1.5, 4.8*1.5])

ax.bar(x, y2, label='', color='#1fbeeb')
ax.set_ylabel('Median Time (in s)')
ax.set_xlabel('b-value')
ax.set_xticks(x)
ax.set_xticklabels(x_values)
ax.set_ylim((0, 10))

for i in range(len(x)):
    plt.text(i, y2[i], y2[i], ha = 'center')

plt.title("Runtime for different b-values")
plt.show()

plt.rcParams.update({'font.size': 10})

# %%
plt.rcParams.update({'font.size': 12})
y= [5.2, 4.76]
y2= [8.1, 37.2]
x_values = ["2-opt", "3-opt"]
x=np.arange(len(x_values))

fig, ax = plt.subplots(figsize=[6.4*1.5, 4.8*1.5])

ax.bar(x, y, label='Percent Error', color='#dc3c06')
ax.set_ylabel('PercentError')
ax.set_xlabel('Strategy')
ax.set_xticks(x)
ax.set_xticklabels(x_values)
ax.set_ylim((0, 10))

for i in range(len(x)):
    plt.text(i, y[i], f"{round(y[i],1)}%", ha = 'center')

plt.title("Error for different local search strategies (walk)")
plt.show()
plt.rcParams.update({'font.size': 10})

# %%
plt.rcParams.update({'font.size': 12})

fig, ax = plt.subplots(figsize=[6.4*1.5, 4.8*1.5])

ax.bar(x, y2, label='', color='#1fbeeb')
ax.set_ylabel('Median Time (in s)')
ax.set_xlabel('Strategy')
ax.set_xticks(x)
ax.set_xticklabels(x_values)
ax.set_ylim((0, 50))

for i in range(len(x)):
    plt.text(i, y2[i], y2[i], ha = 'center')

plt.title("Runtime for different local search strategies (walk)")
plt.show()

plt.rcParams.update({'font.size': 10})

# %%
def toRoundedThousandString(x):
    return str(int(round(x/1000))) + "k"

# %% [markdown]
# ## eil101

# %% [markdown]
# ### Benchmark

# %%
data = pd.read_csv(f'{DATA_PATH}eil101 21_10_2023, 03:04.csv', header=None).values
data2 = pd.read_csv(f'{DATA_PATH}eil101 04_11_2023, 05:20.csv', header=None).values
plt.plot(data, color='blue', label='Benchmark')
plt.plot(data2[:1_000_000], color='red', label='TopN')
plt.plot(len(data)-1, data[-1], marker='o', color='blue', label=f'{round(data[-1][0])}')
plt.plot(1_000_000, data2[1_000_000], marker='o', color='red', label=f'{round(data2[1_000_000][0])}')
plt.axhline(y=629, color='black', linestyle='-.', label='629 (Optimum)')
plt.ylabel('Tour cost')
plt.xlabel('Iterations (In millions)')
plt.ylim(0)
plt.title("Cost of best tour over iterations (eil101)")
plt.legend()
plt.show()

# %% [markdown]
# ### Join Top N (25%)

# %%
data = pd.read_csv(f'{DATA_PATH}eil101 04_11_2023, 05:20.csv', header=None).values
plt.plot(data)
plt.plot(0, data[0], marker='o', color='red', label=f'{round(data[0][0])}')
plt.plot(1_000_000, data[1_000_000], marker='o', color='green', label=f'{round(data[1_000_000][0])}')
plt.axhline(y=629, color='black', linestyle='-.', label='629 (Optimum)')
plt.ylabel('Tour cost')
plt.xlabel('Iterations (In millions)')
plt.ylim(0)
plt.xlim((0, 1e6))
plt.title("Cost of best tour over iterations (eil101)")
plt.legend()
plt.show()

# %% [markdown]
# ## rat575

# %% [markdown]
# ### Benchmark

# %%
data = pd.read_csv(f'{DATA_PATH}rat575 04_11_2023, 05:44.csv', header=None).values
data2 = pd.read_csv(f'{DATA_PATH}rat575 04_11_2023, 05:46.csv', header=None).values
OPT = 6773
plt.plot(data, color='blue', label='Benchmark') # 35639.0 ms
plt.plot(data2, color='red', label='TopN') # 47491.0 ms
plt.plot(len(data)-1, data[-1], marker='o', color='blue', label=f'{round(data[-1][0])}')
plt.plot(len(data2)-1, data2[-1], marker='o', color='red', label=f'{round(data2[-1][0])}')
plt.axhline(y=OPT, color='black', linestyle='-.', label=f'{OPT} (Optimum)')
plt.ylabel('Tour cost')
plt.xlabel('Iterations')
plt.title("Cost of best tour over iterations (rat575)")
plt.legend()
plt.show()

# %% [markdown]
# ## r5934

# %% [markdown]
# ### Benchmark

# %%
data = pd.read_csv(f'{DATA_PATH}rl5934 04_11_2023, 06:03.csv', header=None).values
data2 = pd.read_csv(f'{DATA_PATH}rl5934 04_11_2023, 05:58.csv', header=None).values
OPT=556045

plt.plot(data, color='blue', label='Benchmark') # 218520.0 ms
plt.plot(data2, color='red', label='TopN') # 323675.0 ms
plt.plot(len(data)-1, data[-1], marker='o', color='blue', label=toRoundedThousandString(data[-1][0]))
plt.plot(len(data2)-1, data2[-1], marker='o', color='red', label=toRoundedThousandString(data2[-1][0]))
plt.axhline(y=OPT, color='black', linestyle='-.', label=f'{toRoundedThousandString(OPT)} (Optimum)')
plt.ylabel('Tour cost (In millions)')
plt.yscale('log')
plt.xlabel('Iterations (In millions)')
plt.title("Cost of best tour over iterations (rl5934)")
plt.legend()
plt.show()

# %% [markdown]
# ## p654

# %%
data = pd.read_csv(f'{DATA_PATH}p654 05_11_2023, 04:36.csv', header=None).values
data2 = pd.read_csv(f'{DATA_PATH}p654 05_11_2023, 04:34.csv', header=None).values
OPT=34643

plt.plot(data, color='blue', label='Benchmark') # 38799.0 ms
plt.plot(data2, color='red', label='TopN') # 37578.0 ms
plt.plot(len(data)-1, data[-1], marker='o', color='blue', label=toRoundedThousandString(data[-1][0]))
plt.plot(len(data2)-1, data2[-1], marker='o', color='red', label=toRoundedThousandString(data2[-1][0]))
plt.axhline(y=OPT, color='black', linestyle='-.', label=f'{toRoundedThousandString(OPT)} (Optimum)')
plt.ylabel('Tour cost (In millions)')
plt.yscale('log')
plt.xlabel('Iterations (In millions)')
plt.title("Cost of best tour over iterations (p654)")
plt.legend()
plt.show()

# %% [markdown]
# ### dsj1000

# %%
data = pd.read_csv(f'{DATA_PATH}dsj1000 05_11_2023, 05:07.csv', header=None).values
data2 = pd.read_csv(f'{DATA_PATH}dsj1000 05_11_2023, 05:06.csv', header=None).values
OPT=18660188

plt.plot(data, color='blue', label='Benchmark') # 13592.0 ms
plt.plot(data2, color='red', label='TopN') # 45396.0 ms
plt.plot(len(data)-1, data[-1], marker='o', color='blue', label=toRoundedThousandString(data[-1][0]))
plt.plot(len(data2)-1, data2[-1], marker='o', color='red', label=toRoundedThousandString(data2[-1][0]))
plt.axhline(y=OPT, color='black', linestyle='-.', label=f'{toRoundedThousandString(OPT)} (Optimum)')
plt.ylabel('Tour cost (In millions)')
plt.yscale('log')
plt.xlabel('Iterations (In millions)')
plt.title("Cost of best tour over iterations (dsj1000)")
plt.legend()
plt.show()

# %%
data_cost = pd.read_csv(f'{DATA_PATH}eil101 10_12_2023, 04:16_birds.csv', header=None).values
data_cost_2 = pd.read_csv(f'{DATA_PATH}eil101 10_12_2023, 08:10_birds.csv', header=None).values
OPT=629
n_birds = np.arange(5, 1001, 5)
n_birds_label = np.arange(5, 1011, 100)

fig, ax1 = plt.subplots(layout='constrained')

ax1.plot(n_birds, data_cost, label='Default algorithm', color='green')
ax1.plot(n_birds, data_cost_2, label='Improved', color='blue')
plt.axhline(y=OPT, color='black', linestyle='-.', label=f'{OPT} (Optimum)')
ax1.set_ylabel('Tour cost')
ax1.set_xlabel('Birds')
ax1.set_xticks(n_birds_label)
ax1.set_xticklabels(n_birds_label)

plt.title("Effect of number of birds (eil101)")
plt.legend()
plt.show()

# %%
data_cost = pd.read_csv(f'{DATA_PATH}pa561_birds.csv', header=None).values
data_time = pd.read_csv(f'{DATA_PATH}pa561_time.csv', header=None).values

n_birds = np.arange(5, 1001, 5)
n_birds_label = np.arange(5, 1001, 100)

fig, ax1 = plt.subplots(layout='constrained')
ax2 = ax1.twinx()


ax1.plot(n_birds, data_cost, label='Cost', color='green')
ax1.set_ylabel('Tour cost')
ax1.set_xlabel('Birds')
ax1.set_xticks(n_birds_label)
ax1.set_xticklabels(n_birds_label)

ax2.plot(n_birds, data_time, label='Cost', color='red')
ax2.set_ylabel('Time (ms)')

plt.title("Effect of number of birds (pa561)")
plt.show()

# %%
data_cost = pd.read_csv(f'{DATA_PATH}ali53529_10_2023, 05:16_birds.csv', header=None).values
data_time = pd.read_csv(f'{DATA_PATH}ali53529_10_2023, 05:16_time.csv', header=None).values
data_rounds = pd.read_csv(f'{DATA_PATH}ali53529_10_2023, 05:16_rounds.csv', header=None).values

n_birds = np.arange(5, 1001, 5)
n_birds_label = np.arange(5, 1011, 100)

fig, ax1 = plt.subplots(layout='constrained')
ax2 = ax1.twinx()


ax1.plot(n_birds, data_cost, label='Cost', color='green')
ax1.set_ylabel('Minimum tour cost', color='green')
ax1.set_xlabel('Birds')
ax1.set_xticks(n_birds_label)
ax1.set_xticklabels(n_birds_label)

ax2.plot(n_birds, data_time, label='Time', color='red')
ax2.set_ylabel('Time (ms)', color='red')
fig.legend(loc='upper left', bbox_to_anchor=(0.15, 0.9))

plt.title("Effect of number of birds\n(ali535)")
plt.show()

# %%
fig, ax1 = plt.subplots(layout='constrained')


ax1.plot(n_birds, data_rounds)
ax1.set_ylabel('Moves per bird')
ax1.set_yscale(value='log')
ax1.set_xlabel('Birds')
ax1.set_xticks(n_birds_label)
ax1.set_xticklabels(n_birds_label)
ax1.plot(n_birds[0], data_rounds[0], marker='o', color='green', label=f'{data_rounds[0][0]+1}')
ax1.plot(n_birds[-1], data_rounds[-1], marker='o', color='red', label=f'{data_rounds[-1][0]+1}')
ax1.legend()

plt.title("Effect of number of birds on moves per bird\n(ali535)")
plt.show()

# %%
data_cost = pd.read_csv(f'{DATA_PATH}ali53529_10_2023, 06:29_birds.csv', header=None).values
data_time = pd.read_csv(f'{DATA_PATH}ali53529_10_2023, 06:29_time.csv', header=None).values
data_rounds = pd.read_csv(f'{DATA_PATH}ali53529_10_2023, 06:29_rounds.csv', header=None).values

n_birds = np.arange(5, 1001, 5)
n_birds_label = np.arange(5, 1011, 100)

fig, ax1 = plt.subplots(layout='constrained')
ax2 = ax1.twinx()


ax1.plot(n_birds, data_cost, label='Cost', color='green')
ax1.set_ylabel('Minimum tour cost', color='green')
ax1.set_xlabel('Birds')
ax1.set_xticks(n_birds_label)
ax1.set_xticklabels(n_birds_label)

ax2.plot(n_birds, data_time, label='Time', color='red')
ax2.set_ylabel('Time (ms)', color='red')
fig.legend(loc='upper left', bbox_to_anchor=(0.15, 0.9))

plt.title("Effect of number of birds\n(ali535)")
plt.show()
